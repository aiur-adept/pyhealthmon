# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('/home/oem/workspace/pyhealthmon/health.csv')

# Drop rows with null values
df = df.dropna()

# Extract relevant columns for correlation matrix
columns_of_interest = ['calm', 'joy', 'unified', 'reflection', 'community', 'generosity', 'patience', 'clarity', 'healing', 'effort']
df_selected = df[columns_of_interest]

df
# Out:
#                           date  calm  joy  unified  reflection  community  \
# 0   2023-12-29 00:00:00.000000     6    7        7           7          8
# 1   2023-12-30 00:00:00.000000     7    6        7           5          8
# 2   2023-12-31 00:00:00.000000     8    8        8           8          8
# 3   2024-01-01 00:00:00.000000     7    7        7           7          6
# 4   2024-01-02 00:00:00.000000     7    8        6           6          7
# 5   2024-01-03 00:00:00.000000     7    8        8           7          8
# 6   2024-01-04 00:00:00.000000     8    9        8           8          8
# 7   2024-01-05 00:00:00.000000     8    8        8           7          8
# 8   2024-01-06 00:00:00.000000     9    9        8           7          9
# 9   2024-01-07 00:00:00.000000     7    8        8           7          7
# 10  2024-01-13 15:43:57.622331     8    8        8           8          8
# 11  2024-01-14 11:59:41.686932     8    6        7           9          9
# 12  2024-01-17 10:05:09.588740     7    8        6           7          9
# 13  2024-01-18 17:50:12.795438     7    8        7           7          8
# 14  2024-01-20 09:37:05.329464     8    8        8           7          9
# 15  2024-01-22 19:26:19.600874     8    8        8           9          8
#
#     generosity  patience  clarity  healing  effort
# 0            9         6        7        8       8
# 1            7         8        9        8       8
# 2            8         8        8        8       8
# 3            7         7        7        6       7
# 4            7         6        6        5       7
# 5            8         5        5        8       9
# 6            8         8        8        8       9
# 7            8         8        8        8       9
# 8            9         9        8        8       8
# 9            8         8        8        7       9
# 10           8         8        8        8       8
# 11           8         8        8        8       9
# 12           8         7        7        7       9
# 13           7         7        7        7       9
# 14           8         8        8        8       9
# 15           9         8        8        8       9

# %%
df_selected.sum().sort_values(ascending=False)
# Out:
# effort        135
# community     128
# generosity    127
# joy           124
# calm          120
# clarity       120
# healing       120
# unified       119
# patience      119
# reflection    116
# dtype: int64

# %%
# Calculate the correlation matrix
correlation_matrix = df_selected.corr()

# Display the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
df.boxplot(figsize=(20, 10))
# Out:
# <Axes: >
